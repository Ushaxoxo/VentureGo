# %%
import pandas as pd
import matplotlib.pyplot as plt

categories = ['bakery', 'grocery', 'medicals', 'saloon']
df=pd.read_csv('VentureGo.csv')

width = 0.35

village = [df['village'][i] for i in range(52)]
for i in range(52):
  condi= df['village'] == village[i]

  exist = df.loc[condi, 'existing_ct'].values
  need = df.loc[condi, 'need_ct'].values

  plt.bar(x - width/2, exist, width, label='existing count')
  plt.bar(x + width/2, need, width, label='needed count')

  plt.xlabel('Shop type')
  plt.ylabel('Customers/day')

  plt.title(village[i])
  plt.xticks(x, categories)

  plt.legend()

  plt.show()
  print()
